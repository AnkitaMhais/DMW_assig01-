# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/Book1.csv")
data1=pd.read_csv("/content/Book2.csv")

# %%
print(data)
# Out:
#    SID    Name   Dept
# 0    1  Ankita   Comp
# 1    2  Shweta   Comp
# 2    3     Sai     IT
# 3    4     Ram   Mech
# 4    5     Raj  civil

# %%
print(data1)
# Out:
#    SID  Marks
# 0    1      86
# 1    2      75
# 2    3      80
# 3    4      87
# 4    5      90

# %%
df = pd.merge(data,data1,on='SID')
print(df)
# Out:
#    SID    Name   Dept  Marks
# 0    1  Ankita   Comp      86
# 1    2  Shweta   Comp      75
# 2    3     Sai     IT      80
# 3    4     Ram   Mech      87
# 4    5     Raj  civil      90
